# %%
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15874, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 15874 (delta 47), reused 45 (delta 15), pack-reused 15768
# Receiving objects: 100% (15874/15874), 14.69 MiB | 24.26 MiB/s, done.
# Resolving deltas: 100% (10856/10856), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 606.9/606.9 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="7HVVaz41SrDaeuV024q4")
project = rf.workspace("vellore-institute-of-technology-irutr").project("brain-tumour-x4x6y")
dataset = project.version(1).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Brain-Tumour-1 in yolov5pytorch:: 100%|██████████| 260/260 [00:00<00:00, 2345.29it/s]

# %%
import tensorflow as tf
import os
import cv2
import numpy as np

# %%
image_folder = '/content/yolov5/Brain-Tumour-1/valid/images'
image_shape = (640, 640) # desired shape of the images
image_files = os.listdir(image_folder)
images = []
for filename in image_files:
    img = cv2.imread(os.path.join(image_folder, filename))
    img = cv2.resize(img, image_shape)
    images.append(img)
images = np.array(images)
images = images / 640.0

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/Brain-Tumour-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp2/weights/last.pt'], source=/content/yolov5/Brain-Tumour-1/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 262, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 257, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov5/detect.py", line 99, in run
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp3/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights runs/train/exp2/weights/last.pt --cache
# Out:
# train: weights=runs/train/exp2/weights/last.pt, cfg=, data=/content/yolov5/Brain-Tumour-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp5/weights/best.pt --img 640 --conf 0.1 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp5/weights/best.pt'], source=/content/yolov5/Brain-Tumour-1/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 262, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 257, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov5/detect.py", line 99, in run
# ...

# %%
# !python test.py --weights runs/train/exp5/weights/best.pt --data {dataset.location}/data.yaml --img 640 --conf 0.4 --iou 0.5
# Out:
# python3: can't open file '/content/yolov5/test.py': [Errno 2] No such file or directory

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/yolov5/runs/train/exp/results.csv")

# %%
df.head()
# Out:
#                   epoch        train/box_loss        train/obj_loss  \
# 0                     0              0.121790              0.031750
# 1                     1              0.111130              0.028957
# 2                     2              0.105100              0.028078
# 3                     3              0.093457              0.028470
# 4                     4              0.082916              0.027026
#
#          train/cls_loss     metrics/precision        metrics/recall  \
# 0                     0              0.002500               0.69231
# 1                     0              0.002361               0.65385
# 2                     0              0.002500               0.69231
# 3                     0              0.032344               0.19231
# 4                     0              0.003194               0.88462
#
#         metrics/mAP_0.5  metrics/mAP_0.5:0.95          val/box_loss  \
# 0              0.003145              0.000631              0.119690
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp4/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
# !python detect.py --weights runs/train/exp5/weights/best.pt --img 640 --conf 0.1 --source {dataset.location}/valid/images
# Out:
# detect: weights=['runs/train/exp5/weights/best.pt'], source=/content/yolov5/Brain-Tumour-1/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 262, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 257, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov5/detect.py", line 99, in run
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp5/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")
